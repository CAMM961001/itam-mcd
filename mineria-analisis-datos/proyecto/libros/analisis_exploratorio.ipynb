# %% [markdown]
# # Análisis Exploratorio de Datos

# %%
import os
import numpy as np
import pandas as pd

# %%
path_universal = "C:\\Users\\Miguel\\Documents\\Github\\itam-mcd\\mineria-analisis-datos\\proyecto"
os.listdir(path_universal)
# Out:
# ['datos', 'libros', 'presentaciones', 'README.md']

# %%
path_datos = os.path.join(path_universal, "datos")
os.listdir(path_datos)
# Out:
# ['circuits.csv',
#  'constructors.csv',
#  'constructor_results.csv',
#  'constructor_standings.csv',
#  'drivers.csv',
#  'driver_standings.csv',
#  'lap_times.csv',
#  'pit_stops.csv',
#  'qualifying.csv',
#  'races.csv',
#  'results.csv',
#  'seasons.csv',
#  'sprint_results.csv',
#  'status.csv']

# %% [markdown]
# ## Tabla de circuitos
# Variables y tipo de variable en la tabla

# %%
circuits = pd.read_csv(os.path.join(path_datos, 'circuits.csv'))
circuits
# Out:
#     circuitId   circuitRef                                  name  \
# 0           1  albert_park        Albert Park Grand Prix Circuit
# 1           2       sepang          Sepang International Circuit
# 2           3      bahrain         Bahrain International Circuit
# 3           4    catalunya        Circuit de Barcelona-Catalunya
# 4           5     istanbul                         Istanbul Park
# ..        ...          ...                                   ...
# 71         75     portimao    Autódromo Internacional do Algarve
# 72         76      mugello  Autodromo Internazionale del Mugello
# 73         77       jeddah               Jeddah Corniche Circuit
# 74         78       losail          Losail International Circuit
# 75         79        miami         Miami International Autodrome
#
#         location       country       lat        lng  alt  \
# 0      Melbourne     Australia -37.84970  144.96800   10
# 1   Kuala Lumpur      Malaysia   2.76083  101.73800   18
# ...

# %%
circuits.dtypes
# Out:
# circuitId       int64
# circuitRef     object
# name           object
# location       object
# country        object
# lat           float64
# lng           float64
# alt            object
# url            object
# dtype: object

# %%
circuits.describe()
# Out:
#        circuitId        lat         lng
# count  76.000000  76.000000   76.000000
# mean   39.355263  33.407770    2.606284
# std    22.680214  22.958321   64.553438
# min     1.000000 -37.849700 -118.189000
# 25%    19.750000  32.417775   -9.250838
# 50%    39.500000  41.061100    4.128885
# 75%    58.250000  47.020150   21.404850
# max    79.000000  57.265300  144.968000
